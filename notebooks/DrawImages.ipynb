# %%
# Change to parent directory

import os

os.chdir(os.pardir)
print(os.getcwd())
# Out:
# /mnt/d/linux/bin/draw-fun-sql

# %%
from draw.query_images import collect_queries, query_serialize_image
from draw.draw import draw_complete_image

default_db = os.path.join(os.getcwd(), 'database', 'drawfun.db')

queries = collect_queries(os.getcwd())

images = []
for query in queries:
    images.append(
        query_serialize_image(query, default_db)
    )

# %%
new_img = draw_complete_image(images)

# %%
new_img
# Out:
# <PIL.Image.Image image mode=RGB size=512x256>

# %%
images[0].thumbnail((128,128))
